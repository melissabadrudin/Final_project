# %%
#!python
#Imports
import time
import  requests, bs4
#Variaveis
marca=[]
modelo=[]
combustivel=[]
ano=[]
km=[]
potencia=[]
portas=[]
lugares=[]
mudancas=[]
potencia=[]
cilindrada=[]
caixa=[]
ac=[]
condition=[]
precos=[]
#Primeira página. Caso pretenda recomeçar, apenas troque este valor para
#a última página visitada.
pagina=1

pages_file = open('pages.txt','r')
pages_limit=pages_file.readline()

while pagina<=int(pages_limit):
    try:
        destaques=requests.get('https://www.standvirtual.com/carros/?search%5Border%5D=created_at%3Adesc&page='+str(pagina)) #Permite a cada iteração visitar uma página diferente
        anunciosNaoProcessados=bs4.BeautifulSoup(destaques.text,"html.parser")

        print('teste')
        anuncios=anunciosNaoProcessados.findAll('a',"offer-item__photo-link") #Procura qualquer elemento "a" com o nome de classe descrito.
        
        ficheiro=open('precos2.csv','a') #Inicialização do ficheiro csv para guardar os dados
        
        #Para cada link obtido em anuncios, retirar a informação prentendida de cada veículo.
        for i in range(len(anuncios)):
            
            res=requests.get(anuncios[i].get('href'))
            res.raise_for_status()
            paginasoup=bs4.BeautifulSoup(res.text, "html.parser")
            pagina2=paginasoup.findAll("li","offer-params__item")
            string3=paginasoup.findAll("span","offer-price__number")
            for j in range(len(pagina2)):
                string=pagina2[j].getText().replace(" ","")
                string2=[line for line in string.split('\n') if line.strip() !='']
                if string2[0]=='Marca':
                    marca.append(string2[1])
                elif string2[0]=='Modelo':
                    modelo.append(string2[1])
                elif string2[0]=='Combustível':
                    combustivel.append(string2[1])
                elif string2[0]=='Quilómetros':
                    km.append(string2[1].replace('km',''))
                elif string2[0]=='Potência':
                    potencia.append(string2[1])
                elif string2[0]=='Nºdeportas':
                    portas.append(string2[1])
                elif string2[0]=='Lotação':
                    lugares.append(string2[1])
                elif string2[0]=='NúmerodeMudanças':
                    mudancas.append(string2[1])
                elif string2[0]=='AnodeRegisto':
                    ano.append(string2[1])
                elif string2[0]=='Potência':
                    potencia.append(string2[1])
                elif string2[0]=='Cilindrada':
                    cilindrada.append(string2[1].replace('cm3',''))
                elif string2[0]=='TipodeCaixa':
                    caixa.append(string2[1])
                elif string2[0]=='ArCondicionado':
                    ac.append(string2[1])
                elif string2[0]=='Condição':
                    condition.append(string2[1])

            #Limpar a informação de espaços em branco e da indicação da moeda(EUR)
            precos.append(string3[0].getText().replace(" ","").replace('EUR',''))
            
        for j in range(min(len(marca),len(modelo),len(ano),len(precos),len(portas),len(lugares),len(mudancas))):
            ficheiro.write(str(marca[j])+','+str(modelo[j])+','+str(ano[j])+','+str(km[j])+','+str(portas[j])+','+str(lugares[j])+','+str(mudancas[j])+','+str(combustivel[j])+','+str(potencia[j])+','+str(cilindrada[j])+','+str(caixa[j])+','+str(ac[j])+','+str(condition[j])+','+str(precos[j]))
            
        print("Página "+str(pagina)+" concluída com sucesso")
        ficheiro.close()
        marca=[]
        modelo=[]
        combustivel=[]
        ano=[]
        km=[]
        potencia=[]
        portas=[]
        lugares=[]
        mudancas=[]
        precos=[]
        #Passar para a página seguinte.
    except:
        print('error_continue')
    pagina=pagina+1
# Out:
# teste
# Página 1 concluída com sucesso
# teste
# Página 2 concluída com sucesso
# teste
# Página 3 concluída com sucesso
# teste
# Página 4 concluída com sucesso
# teste
# Página 5 concluída com sucesso
# teste
# Página 6 concluída com sucesso
# teste
# Página 7 concluída com sucesso
# teste
# Página 8 concluída com sucesso
# teste
# Página 9 concluída com sucesso
# teste
# Página 10 concluída com sucesso
# teste
# Página 11 concluída com sucesso
# teste
# Página 12 concluída com sucesso
# teste
# Página 13 concluída com sucesso
# teste
# Página 14 concluída com sucesso
# teste
# Página 15 concluída com sucesso
# teste
# Página 16 concluída com sucesso
# teste
# Página 17 concluída com sucesso
# teste
# Página 18 concluída com sucesso
# teste
# Página 19 concluída com sucesso
# teste
# Página 20 concluída com sucesso
# teste
# Página 21 concluída com sucesso
# teste
# Página 22 concluída com sucesso
# teste
# Página 23 concluída com sucesso
# teste
# Página 24 concluída com sucesso
# teste
# Página 25 concluída com sucesso
# teste
# Página 26 concluída com sucesso
# teste
# Página 27 concluída com sucesso
# teste
# Página 28 concluída com sucesso
# teste
# Página 29 concluída com sucesso
# teste
# Página 30 concluída com sucesso
# teste
# Página 31 concluída com sucesso
# teste
# Página 32 concluída com sucesso
# teste
# Página 33 concluída com sucesso
# teste
# Página 34 concluída com sucesso
# teste
# Página 35 concluída com sucesso
# teste
# Página 36 concluída com sucesso
# teste
# Página 37 concluída com sucesso
# teste
# Página 38 concluída com sucesso
# teste
# Página 39 concluída com sucesso
# teste
# Página 40 concluída com sucesso
# teste
# Página 41 concluída com sucesso
# teste
# Página 42 concluída com sucesso
# teste
# Página 43 concluída com sucesso
# teste
# Página 44 concluída com sucesso
# teste
# Página 45 concluída com sucesso
# teste
# Página 46 concluída com sucesso
# teste
# Página 47 concluída com sucesso
# teste
# Página 48 concluída com sucesso
# teste
# Página 49 concluída com sucesso
# teste
# Página 50 concluída com sucesso
# teste
# Página 51 concluída com sucesso
# teste
# Página 52 concluída com sucesso
# teste
# Página 53 concluída com sucesso
# teste
# Página 54 concluída com sucesso
# teste
# Página 55 concluída com sucesso
# teste
# Página 56 concluída com sucesso
# teste
# Página 57 concluída com sucesso
# teste
# Página 58 concluída com sucesso
# teste
# Página 59 concluída com sucesso
# teste
# Página 60 concluída com sucesso
# teste
# Página 61 concluída com sucesso
# teste
# Página 62 concluída com sucesso
# teste
# Página 63 concluída com sucesso
# teste
# Página 64 concluída com sucesso
# teste
# Página 65 concluída com sucesso
# teste
# Página 66 concluída com sucesso
# teste
# Página 67 concluída com sucesso
# teste
# Página 68 concluída com sucesso
# teste
# Página 69 concluída com sucesso
# teste
# Página 70 concluída com sucesso
# teste
# Página 71 concluída com sucesso
# teste
# Página 72 concluída com sucesso
# teste
# Página 73 concluída com sucesso
# teste
# Página 74 concluída com sucesso
# teste
# Página 75 concluída com sucesso
# teste
# Página 76 concluída com sucesso
# teste
# Página 77 concluída com sucesso
# teste
# Página 78 concluída com sucesso
# teste
# Página 79 concluída com sucesso
# teste
# Página 80 concluída com sucesso
# teste
# Página 81 concluída com sucesso
# teste
# Página 82 concluída com sucesso
# teste
# Página 83 concluída com sucesso
# teste
# Página 84 concluída com sucesso
# teste
# Página 85 concluída com sucesso
# teste
# error_continue
# teste
# Página 87 concluída com sucesso
# teste
# Página 88 concluída com sucesso
# teste
# Página 89 concluída com sucesso
# teste
# Página 90 concluída com sucesso
# teste
# Página 91 concluída com sucesso
# teste
# Página 92 concluída com sucesso
# teste
# Página 93 concluída com sucesso
# teste
# Página 94 concluída com sucesso
# teste
# Página 95 concluída com sucesso
# teste
# Página 96 concluída com sucesso
# teste
# Página 97 concluída com sucesso
# teste
# Página 98 concluída com sucesso
# teste
# Página 99 concluída com sucesso
# teste
# Página 100 concluída com sucesso
# teste
# Página 101 concluída com sucesso
# teste
# Página 102 concluída com sucesso
# teste
# Página 103 concluída com sucesso
# teste
# Página 104 concluída com sucesso
# teste
# Página 105 concluída com sucesso
# teste
# Página 106 concluída com sucesso
# teste
# Página 107 concluída com sucesso
# teste
# Página 108 concluída com sucesso
# teste
# Página 109 concluída com sucesso
# teste
# Página 110 concluída com sucesso
# teste
# Página 111 concluída com sucesso
# teste
# Página 112 concluída com sucesso
# teste
# Página 113 concluída com sucesso
# teste
# Página 114 concluída com sucesso
# teste
# Página 115 concluída com sucesso
# teste
# Página 116 concluída com sucesso
# teste
# Página 117 concluída com sucesso
# teste
# Página 118 concluída com sucesso
# teste
# Página 119 concluída com sucesso
# teste
# Página 120 concluída com sucesso
# teste
# Página 121 concluída com sucesso
# teste
# Página 122 concluída com sucesso
# teste
# Página 123 concluída com sucesso
# teste
# Página 124 concluída com sucesso
# teste
# Página 125 concluída com sucesso
# teste
# Página 126 concluída com sucesso
# teste
# Página 127 concluída com sucesso
# teste
# Página 128 concluída com sucesso
# teste
# Página 129 concluída com sucesso
# teste
# Página 130 concluída com sucesso
# teste
# Página 131 concluída com sucesso
# teste
# Página 132 concluída com sucesso
# teste
# Página 133 concluída com sucesso
# teste
# Página 134 concluída com sucesso
# teste
# Página 135 concluída com sucesso
# teste
# Página 136 concluída com sucesso
# teste
# Página 137 concluída com sucesso
# teste
# error_continue
# teste
# Página 139 concluída com sucesso
# teste
# Página 140 concluída com sucesso
# teste
# Página 141 concluída com sucesso
# teste
# Página 142 concluída com sucesso
# teste
# Página 143 concluída com sucesso
# teste
# Página 144 concluída com sucesso
# teste
# Página 145 concluída com sucesso
# teste
# Página 146 concluída com sucesso
# teste
# Página 147 concluída com sucesso
# teste
# Página 148 concluída com sucesso
# teste
# Página 149 concluída com sucesso
# teste
# Página 150 concluída com sucesso
# teste
# Página 151 concluída com sucesso
# teste
# Página 152 concluída com sucesso
# teste
# Página 153 concluída com sucesso
# teste
# Página 154 concluída com sucesso
# teste
# Página 155 concluída com sucesso
# teste
# Página 156 concluída com sucesso
# teste
# Página 157 concluída com sucesso
# teste
# Página 158 concluída com sucesso
# teste
# Página 159 concluída com sucesso
# teste
# Página 160 concluída com sucesso
# teste
# Página 161 concluída com sucesso
# teste
# Página 162 concluída com sucesso
# teste
# Página 163 concluída com sucesso
# teste
# Página 164 concluída com sucesso
# teste
# Página 165 concluída com sucesso
# teste
# Página 166 concluída com sucesso
# teste
# Página 167 concluída com sucesso
# teste
# Página 168 concluída com sucesso
# teste
# Página 169 concluída com sucesso
# teste
# Página 170 concluída com sucesso
# teste
# Página 171 concluída com sucesso
# teste
# Página 172 concluída com sucesso
# teste
# Página 173 concluída com sucesso
# teste
# Página 174 concluída com sucesso
# teste
# Página 175 concluída com sucesso
# teste
# Página 176 concluída com sucesso
# teste
# Página 177 concluída com sucesso
# teste
# Página 178 concluída com sucesso
# teste
# Página 179 concluída com sucesso
# teste
# Página 180 concluída com sucesso
# teste
# Página 181 concluída com sucesso
# teste
# Página 182 concluída com sucesso
# teste
# Página 183 concluída com sucesso
# teste
# Página 184 concluída com sucesso
# teste
# Página 185 concluída com sucesso
# teste
# Página 186 concluída com sucesso
# teste
# Página 187 concluída com sucesso
# teste
# Página 188 concluída com sucesso
# teste
# Página 189 concluída com sucesso
# teste
# Página 190 concluída com sucesso
# teste
# error_continue
# teste
# Página 192 concluída com sucesso
# teste
# Página 193 concluída com sucesso
# teste
# Página 194 concluída com sucesso
# teste
# Página 195 concluída com sucesso
# teste
# Página 196 concluída com sucesso
# teste
# Página 197 concluída com sucesso
# teste
# Página 198 concluída com sucesso
# teste
# Página 199 concluída com sucesso
# teste
# Página 200 concluída com sucesso
# teste
# Página 201 concluída com sucesso
# teste
# Página 202 concluída com sucesso
# teste
# Página 203 concluída com sucesso
# teste
# Página 204 concluída com sucesso
# teste
# Página 205 concluída com sucesso
# teste
# Página 206 concluída com sucesso
# teste
# Página 207 concluída com sucesso
# teste
# Página 208 concluída com sucesso
# teste
# Página 209 concluída com sucesso
# teste
# Página 210 concluída com sucesso
# teste
# Página 211 concluída com sucesso
# teste
# Página 212 concluída com sucesso
# teste
# Página 213 concluída com sucesso
# teste
# Página 214 concluída com sucesso
# teste
# Página 215 concluída com sucesso
# teste
# Página 216 concluída com sucesso
# teste
# Página 217 concluída com sucesso
# teste
# Página 218 concluída com sucesso
# teste
# Página 219 concluída com sucesso
# teste
# Página 220 concluída com sucesso
# teste
# Página 221 concluída com sucesso
# teste
# Página 222 concluída com sucesso
# teste
# Página 223 concluída com sucesso
# teste
# Página 224 concluída com sucesso
# teste
# Página 225 concluída com sucesso
# teste
# Página 226 concluída com sucesso
# teste
# Página 227 concluída com sucesso
# teste
# Página 228 concluída com sucesso
# teste
# Página 229 concluída com sucesso
# teste
# Página 230 concluída com sucesso
# teste
# Página 231 concluída com sucesso
# teste
# Página 232 concluída com sucesso
# teste
# Página 233 concluída com sucesso
# teste
# Página 234 concluída com sucesso
# teste
# Página 235 concluída com sucesso
# teste
# Página 236 concluída com sucesso
# teste
# Página 237 concluída com sucesso
# teste
# Página 238 concluída com sucesso
# teste
# Página 239 concluída com sucesso
# teste
# Página 240 concluída com sucesso
# teste
# Página 241 concluída com sucesso
# teste
# Página 242 concluída com sucesso
# teste
# Página 243 concluída com sucesso
# teste
# Página 244 concluída com sucesso
# teste
# Página 245 concluída com sucesso
# teste
# Página 246 concluída com sucesso
# teste
# Página 247 concluída com sucesso
# teste
# Página 248 concluída com sucesso
# teste
# Página 249 concluída com sucesso
# teste
# Página 250 concluída com sucesso
# teste
# Página 251 concluída com sucesso
# teste
# Página 252 concluída com sucesso
# teste
# Página 253 concluída com sucesso
# teste
# Página 254 concluída com sucesso
# teste
# Página 255 concluída com sucesso
# teste
# Página 256 concluída com sucesso
# teste
# Página 257 concluída com sucesso
# teste
# Página 258 concluída com sucesso
# teste
# Página 259 concluída com sucesso
# teste
# Página 260 concluída com sucesso
# teste
# Página 261 concluída com sucesso
# teste
# Página 262 concluída com sucesso
# teste
# Página 263 concluída com sucesso
# teste
# Página 264 concluída com sucesso
# teste
# Página 265 concluída com sucesso
# teste
# Página 266 concluída com sucesso
# teste
# Página 267 concluída com sucesso
# teste
# Página 268 concluída com sucesso
# teste
# Página 269 concluída com sucesso
# teste
# Página 270 concluída com sucesso
# teste
# Página 271 concluída com sucesso
# teste
# Página 272 concluída com sucesso
# teste
# Página 273 concluída com sucesso
# teste
# Página 274 concluída com sucesso
# teste
# Página 275 concluída com sucesso
# teste
# Página 276 concluída com sucesso
# teste
# Página 277 concluída com sucesso
# teste
# Página 278 concluída com sucesso
# teste
# Página 279 concluída com sucesso
# teste
# Página 280 concluída com sucesso
# teste
# Página 281 concluída com sucesso
# teste
# Página 282 concluída com sucesso
# teste
# Página 283 concluída com sucesso
# teste
# Página 284 concluída com sucesso
# teste
# Página 285 concluída com sucesso
# teste
# Página 286 concluída com sucesso
# teste
# Página 287 concluída com sucesso
# teste
# Página 288 concluída com sucesso
# teste
# Página 289 concluída com sucesso
# teste
# Página 290 concluída com sucesso
# teste
# Página 291 concluída com sucesso
# teste
# Página 292 concluída com sucesso
# teste
# Página 293 concluída com sucesso
# teste
# Página 294 concluída com sucesso
# teste
# Página 295 concluída com sucesso
# teste
# Página 296 concluída com sucesso
# teste
# Página 297 concluída com sucesso
# teste
# Página 298 concluída com sucesso
# teste
# Página 299 concluída com sucesso
# teste
# Página 300 concluída com sucesso
# teste
# Página 301 concluída com sucesso
# teste
# Página 302 concluída com sucesso
# teste
# Página 303 concluída com sucesso
# teste
# Página 304 concluída com sucesso
# teste
# Página 305 concluída com sucesso
# teste
# Página 306 concluída com sucesso
# teste
# Página 307 concluída com sucesso
# teste
# Página 308 concluída com sucesso
# teste
# Página 309 concluída com sucesso
# teste
# Página 310 concluída com sucesso
# teste
# Página 311 concluída com sucesso
# teste
# Página 312 concluída com sucesso
# teste
# Página 313 concluída com sucesso
# teste
# Página 314 concluída com sucesso
# teste
# Página 315 concluída com sucesso
# teste
# Página 316 concluída com sucesso
# teste
# Página 317 concluída com sucesso
# teste
# Página 318 concluída com sucesso
# teste
# Página 319 concluída com sucesso
# teste
# Página 320 concluída com sucesso
# teste
# Página 321 concluída com sucesso
# teste
# Página 322 concluída com sucesso
# teste
# Página 323 concluída com sucesso
# teste
# Página 324 concluída com sucesso
# teste
# Página 325 concluída com sucesso
# teste
# Página 326 concluída com sucesso
# teste
# Página 327 concluída com sucesso
# teste
# Página 328 concluída com sucesso
# teste
# Página 329 concluída com sucesso
# teste
# Página 330 concluída com sucesso
# teste
# Página 331 concluída com sucesso
# teste
# Página 332 concluída com sucesso
# teste
# Página 333 concluída com sucesso
# teste
# Página 334 concluída com sucesso
# teste
# Página 335 concluída com sucesso
# teste
# Página 336 concluída com sucesso
# teste
# Página 337 concluída com sucesso
# teste
# Página 338 concluída com sucesso
# teste
# Página 339 concluída com sucesso
# teste
# Página 340 concluída com sucesso
# teste
# Página 341 concluída com sucesso
# teste
# Página 342 concluída com sucesso
# teste
# Página 343 concluída com sucesso
# teste
# Página 344 concluída com sucesso
# teste
# Página 345 concluída com sucesso
# teste
# Página 346 concluída com sucesso
# teste
# Página 347 concluída com sucesso
# teste
# Página 348 concluída com sucesso
# teste
# Página 349 concluída com sucesso
# teste
# Página 350 concluída com sucesso
# teste
# Página 351 concluída com sucesso
# teste
# Página 352 concluída com sucesso
# teste
# Página 353 concluída com sucesso
# teste
# Página 354 concluída com sucesso
# teste
# Página 355 concluída com sucesso
# teste
# Página 356 concluída com sucesso
# teste
# error_continue
# teste
# Página 358 concluída com sucesso
# teste
# Página 359 concluída com sucesso
# teste
# Página 360 concluída com sucesso
# teste
# Página 361 concluída com sucesso
# teste
# Página 362 concluída com sucesso
# teste
# Página 363 concluída com sucesso
# teste
# Página 364 concluída com sucesso
# teste
# Página 365 concluída com sucesso
# teste
# Página 366 concluída com sucesso
# teste
# Página 367 concluída com sucesso
# teste
# Página 368 concluída com sucesso
# teste
# Página 369 concluída com sucesso
# teste
# Página 370 concluída com sucesso
# teste
# Página 371 concluída com sucesso
# teste
# Página 372 concluída com sucesso
# teste
# Página 373 concluída com sucesso
# teste
# Página 374 concluída com sucesso
# teste
# Página 375 concluída com sucesso
# teste
# Página 376 concluída com sucesso
# teste
# Página 377 concluída com sucesso
# teste
# Página 378 concluída com sucesso
# teste
# Página 379 concluída com sucesso
# teste
# Página 380 concluída com sucesso
# teste
# Página 381 concluída com sucesso
# teste
# Página 382 concluída com sucesso
# teste
# Página 383 concluída com sucesso
# teste
# Página 384 concluída com sucesso
# teste
# Página 385 concluída com sucesso
# teste
# Página 386 concluída com sucesso
# teste
# Página 387 concluída com sucesso
# teste
# Página 388 concluída com sucesso
# teste
# Página 389 concluída com sucesso
# teste
# Página 390 concluída com sucesso
# teste
# Página 391 concluída com sucesso
# teste
# Página 392 concluída com sucesso
# teste
# Página 393 concluída com sucesso
# teste
# Página 394 concluída com sucesso
# teste
# Página 395 concluída com sucesso
# teste
# Página 396 concluída com sucesso
# teste
# Página 397 concluída com sucesso
# teste
# Página 398 concluída com sucesso
# teste
# Página 399 concluída com sucesso
# teste
# Página 400 concluída com sucesso
# teste
# Página 401 concluída com sucesso
# teste
# Página 402 concluída com sucesso
# teste
# Página 403 concluída com sucesso
# teste
# Página 404 concluída com sucesso
# teste
# Página 405 concluída com sucesso
# teste
# Página 406 concluída com sucesso
# teste
# Página 407 concluída com sucesso
# teste
# Página 408 concluída com sucesso
# teste
# Página 409 concluída com sucesso
# teste
# Página 410 concluída com sucesso
# teste
# Página 411 concluída com sucesso
# teste
# Página 412 concluída com sucesso
# teste
# Página 413 concluída com sucesso
# teste
# Página 414 concluída com sucesso
# teste
# Página 415 concluída com sucesso
# teste
# Página 416 concluída com sucesso
# teste
# Página 417 concluída com sucesso
# teste
# Página 418 concluída com sucesso
# teste
# Página 419 concluída com sucesso
# teste
# Página 420 concluída com sucesso
# teste
# Página 421 concluída com sucesso
# teste
# Página 422 concluída com sucesso
# teste
# Página 423 concluída com sucesso
# teste
# Página 424 concluída com sucesso
# teste
# Página 425 concluída com sucesso
# teste
# Página 426 concluída com sucesso
# teste
# Página 427 concluída com sucesso
# teste
# Página 428 concluída com sucesso
# teste
# Página 429 concluída com sucesso
# teste
# Página 430 concluída com sucesso
# teste
# Página 431 concluída com sucesso
# teste
# Página 432 concluída com sucesso
# teste
# Página 433 concluída com sucesso
# teste
# Página 434 concluída com sucesso
# teste
# Página 435 concluída com sucesso
# teste
# Página 436 concluída com sucesso
# teste
# Página 437 concluída com sucesso
# teste
# Página 438 concluída com sucesso
# teste
# Página 439 concluída com sucesso
# teste
# Página 440 concluída com sucesso
# teste
# Página 441 concluída com sucesso
# teste
# Página 442 concluída com sucesso
# teste
# Página 443 concluída com sucesso
# teste
# Página 444 concluída com sucesso
# teste
# Página 445 concluída com sucesso
# teste
# Página 446 concluída com sucesso
# teste
# Página 447 concluída com sucesso
# teste
# Página 448 concluída com sucesso
# teste
# Página 449 concluída com sucesso
# teste
# Página 450 concluída com sucesso
# teste
# Página 451 concluída com sucesso
# teste
# Página 452 concluída com sucesso
# teste
# Página 453 concluída com sucesso
# teste
# Página 454 concluída com sucesso
# teste
# Página 455 concluída com sucesso
# teste
# Página 456 concluída com sucesso
# teste
# Página 457 concluída com sucesso
# teste
# Página 458 concluída com sucesso
# teste
# Página 459 concluída com sucesso
# teste
# Página 460 concluída com sucesso
# teste
# Página 461 concluída com sucesso
# teste
# Página 462 concluída com sucesso
# teste
# Página 463 concluída com sucesso
# teste
# Página 464 concluída com sucesso
# teste
# Página 465 concluída com sucesso
# teste
# Página 466 concluída com sucesso
# teste
# Página 467 concluída com sucesso
# teste
# Página 468 concluída com sucesso
# teste
# Página 469 concluída com sucesso
# teste
# Página 470 concluída com sucesso
# teste
# Página 471 concluída com sucesso
# teste
# Página 472 concluída com sucesso
# teste
# Página 473 concluída com sucesso
# teste
# Página 474 concluída com sucesso
# teste
# Página 475 concluída com sucesso
# teste
# Página 476 concluída com sucesso
# teste
# Página 477 concluída com sucesso
# teste
# Página 478 concluída com sucesso
# teste
# Página 479 concluída com sucesso
# teste
# Página 480 concluída com sucesso
# teste
# Página 481 concluída com sucesso
# teste
# Página 482 concluída com sucesso
# teste
# Página 483 concluída com sucesso
# teste
# Página 484 concluída com sucesso
# teste
# Página 485 concluída com sucesso
# teste
# Página 486 concluída com sucesso
# teste
# Página 487 concluída com sucesso
# teste
# Página 488 concluída com sucesso
# teste
# Página 489 concluída com sucesso
# teste
# Página 490 concluída com sucesso
# teste
# Página 491 concluída com sucesso
# teste
# Página 492 concluída com sucesso
# teste
# Página 493 concluída com sucesso
# teste
# Página 494 concluída com sucesso
# teste
# Página 495 concluída com sucesso
# teste
# Página 496 concluída com sucesso
# teste
# Página 497 concluída com sucesso
# teste
# Página 498 concluída com sucesso
# teste
# Página 499 concluída com sucesso
# teste
# Página 500 concluída com sucesso
